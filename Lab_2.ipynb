# %% [markdown]
# <a href="https://colab.research.google.com/github/Muditsinghbora/AIML/blob/main/Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
ss = files.upload()
# Out:
#      <input type="file" id="files-68fcf45c-f904-40cf-819c-6a35eaabe0e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68fcf45c-f904-40cf-819c-6a35eaabe0e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as nd
import matplotlib.pyplot as plt
import seaborn as sns
pd.read_csv('supermarket_sales2.csv')
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69       NaN  26.1415   548.9715
# 1    Electronic accessories       15.28       NaN   3.8200    80.2200
# ...

# %%
df=pd.read_csv('supermarket_sales2.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 995 non-null    float64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.describe()
# Out:
#         Unit price    Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  995.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130    5.503518    15.379369   322.966749   307.58738
# std      26.494628    2.928514    11.708825   245.885335   234.17651
# min      10.080000    1.000000     0.508500    10.678500    10.17000
# 25%      32.875000    3.000000     5.924875   124.422375   118.49750
# 50%      55.230000    5.000000    12.088000   253.848000   241.76000
# 75%      77.935000    8.000000    22.445250   471.350250   448.90500
# max      99.960000   10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 995 non-null    float64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False      True   False  False  False  False    False  False
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   5
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.dropna(inplace=True)#drop rows with missing values(if appropiate)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69       NaN  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28       NaN   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33       NaN  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22       NaN  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31       NaN  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.fillna(df['Quantity'].mean(),inplace=True)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69  5.503518  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28  5.503518   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33  5.503518  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22  5.503518  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31  5.503518  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.histplot(df['Quantity'])
plt.show()

# %%
sns.boxplot(x='Payment',y='Quantity',data=df)
plt.show()

# %%
sns.scatterplot(x='cogs',y='Quantity', data=df)
plt.show()

# %%
sns.countplot(x='Branch',data=df)
plt.show()

# %%
af=df[['Quantity','Unit price','Tax 5%','cogs','gross income','Rating']]
corr=af.corr()
sns.heatmap(corr,annot=True)
plt.show()

# %%
df.groupby('City')['Quantity'].mean()
# Out:
# City
# Mandalay     5.481928
# Naypyitaw    5.583852
# Yangon       5.447100
# Name: Quantity, dtype: float64

# %%
pd.pivot_table(df,index='City',values='Quantity',aggfunc='sum')
# Out:
#               Quantity
# City
# Mandalay   1820.000000
# Naypyitaw  1831.503518
# Yangon     1852.014070
